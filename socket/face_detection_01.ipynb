# %%
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
#정면얼굴검출기
face_detector = dlib.get_frontal_face_detector()

# %%
img = cv2.imread('../data/lena.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()

# %%
faces = face_detector(img)

# %%
for f in faces:
    print("left, top, right, bottom", f.left(), f.top(), f.bottom(), f.right)
    cv2.rectangle(img, (f.left(), f.top()),(f.right(), f.bottom()), (0,0,255), 2)
# Out:
# left, top, right, bottom 228 228 377 <bound method PyCapsule.right of rectangle(228,228,377,377)>

# %%
win = dlib.image_window()
win.set_image(img)
win.add_overlay(faces)

# %%
cv2.imwrite("output.jpg", img)
# Out:
# True

# %%
plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()

# %%
crop = img[f.top():f.bottom(), f.left():f.right()]
plt.figure(figsize=(3,3))
plt.imshow(crop)
plt.show()
